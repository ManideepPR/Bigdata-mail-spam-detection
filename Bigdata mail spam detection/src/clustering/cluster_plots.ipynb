# %%
import numpy as np
import seaborn as sns
import pickle
import pandas as pd

# %%
test_results_filename = "/home/pes1ug19cs334/models/clustering/tr_128.pkl"

# %%
with open(test_results_filename, 'rb') as file:
    tr = pickle.load(file)

# %%
tr
# Out:
# {'X': array([[ 1.21357673,  0.63918717],
#         [-0.20926537,  0.15372923],
#         [ 0.30725275, -0.65168331],
#         ...,
#         [-0.15608079, -0.1823744 ],
#         [ 0.17753195, -0.72571266],
#         [-0.23479445,  0.20133102]]),
#  'y_pred': array([1, 0, 0, ..., 0, 0, 0], dtype=int32),
#  'y_true': array([0., 1., 1., ..., 0., 0., 1.])}

# %%
df_x = pd.DataFrame(tr["X"], columns = ["x1","x2"])

# %%
df.head()
# Out:
#          x1        x2
# 0  1.213577  0.639187
# 1 -0.209265  0.153729
# 2  0.307253 -0.651683
# 3 -0.147232  0.191183
# 4 -0.081349 -0.091152

# %%
df_y = pd.DataFrame(tr['y_true'], columns=['y_true'])

# %%
df_y['y_pred'] = tr['y_pred']

# %%
sns.scatterplot(x=df_x['x1'], y=df_x['x2'], hue=df_y['y_pred'])
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>
